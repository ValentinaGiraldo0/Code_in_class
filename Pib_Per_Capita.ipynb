# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentinaGiraldo0/Code_in_class/blob/main/Pib_Per_Capita.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Information**
#
# * **Name:** Lindsay Valentina Giraldo Martinez
# * **Code** 63191065
# * **ID** 1.001.200.519

# %% [markdown]
# ##**1. Data set**

# %% [markdown]
# ###*1.1. Variable*

# %% [markdown]
# ####**1.1.1. What is Variable?**
#
#
# The variable that will be used to perform the visualization is the `GDP per capita (USD at current prices)` of South America.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**1.1.2. Units**
#
# The DV of GDP is presented in units of thousands of USD (at current prices).

# %% [markdown]
# ####**1.1.3. Individuals**
#
# As mentioned above, they are South American countries, which include `Colombia, Venezuela, Perú, Ecuador, Brazil, Argentina, Bolivia, Paraguay, Uruguay and Chile`.

# %% [markdown]
# ####**1.1.4. Period**
#
# The DV is carried out in `the period from 1960 to 2021`, it is worth mentioning that the data are annual to determine the changes that those periods provided.

# %% [markdown]
# ![image.png](https://sites.google.com/site/americanageograf/_/rsrc/1489519129468/america-del-sur/Mapa-Poltico-de-Sudamrica.gif)

# %% [markdown]
# ###*1.2 Sourse*

# %% [markdown]
# ####**1.2.1. URL**
#
# The main source of information is the world bank
#
# [Banco Mundial](https://datos.bancomundial.org/indicador/NY.GDP.PCAP.CD?end=2021&locations=CO-AR-CL-BR-UY-PY-EC-VE-BO-PE&start=1960)

# %% [markdown]
# ![Time series](https://www.ebankingnews.com/wp-content/uploads/2019/02/bank-01.jpg)

# %% [markdown]
# #**2. Data Visualization**

# %%
# Erase Everything
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# The Libraries
import pandas as pd
import numpy as np # just in case
import plotly.express as px
import plotly.graph_objects as go # graphs other than scatter and bar or customize
import matplotlib.pyplot as plt
import matplotlib.style as style

# %% [markdown]
# ## **2.1. Load data set**

# %%
# Save the file path
p1 = '/content/BASE DE DATOS DV..xlsx'

# Read file
ex = pd.read_excel(p1)

# Check
ex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       62 non-null     int64
#  1   Argentina  60 non-null     float64
#  2   Bolivia    62 non-null     float64
#  3   Brasil     62 non-null     float64
#  4   Chile      62 non-null     float64
#  5   Colombia   62 non-null     float64
#  6   Ecuador    62 non-null     float64
#  7   Perú       62 non-null     float64
#  8   Paraguay   57 non-null     float64
#  9   Uruguay    62 non-null     float64
#  10  Venezuela  55 non-null     float64
# dtypes: float64(10), int64(1)
# memory usage: 5.5 KB

# %%
ex = ex.set_index('DATE', drop = False)  # Drop does nor delete Date
ex.head()
# Out:
#       DATE    Argentina     Bolivia      Brasil       Chile    Colombia  \
# DATE
# 1960  1960          NaN  102.237722  235.946883  505.349325  251.041523
# 1961  1961          NaN  109.061304  232.480546  555.134403  274.052264
# 1962  1962  1155.890717  116.924968  251.348317  638.945360  289.917946
# 1963  1963   850.304579  123.429341  295.631971  655.252249  274.314958
# 1964  1964  1173.238105  136.312362  258.605371  678.128106  328.655032
#
#          Ecuador        Perú  Paraguay     Uruguay    Venezuela
# DATE
# 1960  455.462389  253.264921       NaN  489.350725   955.446418
# 1961  375.221305  277.568763       NaN  601.703003   970.356398
# 1962  315.688704  305.761617       NaN  656.713227  1023.355237
# 1963  368.629584  325.516339       NaN  584.291634  1077.403051
# 1964  440.560234  382.743965       NaN  741.244998   864.471221

# %%
# Base Layout
fig = go.Figure(
   layout = go.Layout(
        updatemenus = [dict(type = "buttons", direction = "down", x = 0, y = -0.2)],
        xaxis = dict(range = ['1958', '2024'],
                     autorange = False, tickwidth = 2,
                     title_text = 'Dates'),
        yaxis = dict(range = [0,20000],
                     autorange = False, tickwidth = 2,
                     title_text = "Thousands of USD"),
        title = 'PIB Per Cápita (USD Current Prices)',
        title_font_size = 30,
        title_x = 0.5
    )
)

# %%
from pandas.io import excel
# Add traces 
init = 1

fig.add_trace(
    go.Scatter(x = ex.DATE[:init],
               y = ex.Chile[:init],
               name = 'Chile',
               visible = True,
               line = dict(color = 'red'),
               mode = 'lines+markers',
               )
)
fig.add_trace(
    go.Scatter(x = [ex.DATE[:init].iloc[-1]],
               y = [ex.Chile[:init].iloc[-1]],
               text = [round(ex.Chile[:init].iloc[-1],2)],
               textfont = dict(color = 'black', size = 10),
               textposition = 'middle right',
               mode = 'markers+text', 
               marker = dict(color = 'red', size = 5, symbol = 'circle', line=dict(width=2, color = 'red')),
               showlegend = False)
)
fig.add_trace(
    go.Scatter(x = ex.DATE[:init],
               y = ex.Argentina[:init],
               name = 'Argentina',
               visible = True,
               line = dict(color = 'rgb(0, 255, 255)'),
               mode = 'lines+markers'
               )
)
fig.add_trace(
    go.Scatter(x = [ex.DATE[:init].iloc[-1]],
               y = [ex.Argentina[:init].iloc[-1]],
               text = [round(ex.Argentina[:init].iloc[-1],2)],
               textfont = dict(color = 'black', size = 10),
               textposition = 'middle right',
               mode = 'markers+text', 
               marker = dict(color = 'rgb(0, 255, 255)', size = 5, symbol = 'circle', line=dict(width=2, color = 'rgb(0, 255, 255)')),
               showlegend = False)
)
fig.add_trace(
    go.Scatter(x = ex.DATE[:init],
               y = ex.Colombia[:init],
               name = 'Colombia',
               visible = True,
               line = dict(color = 'rgb(255, 215, 0)'),
               mode = 'lines+markers'
               )
)
fig.add_trace(
    go.Scatter(x = [ex.DATE[:init].iloc[-1]],
               y = [ex.Colombia[:init].iloc[-1]],
               text = [round(ex.Colombia[:init].iloc[-1],2)],
               textfont = dict(color = 'black', size = 10),
               textposition = 'middle right',
               mode = 'markers+text', 
               marker = dict(color = 'rgb(255, 215, 0)', size = 5, symbol = 'circle', line=dict(width=2, color = 'rgb(255, 215, 0)')),
               showlegend = False)
)
fig.add_trace(
    go.Scatter(x = ex.DATE[:init],
               y = ex.Bolivia[:init],
               name = 'Bolivia',
               visible = True,
               line = dict(color = 'rgb(60, 179, 113)'),
               mode = 'lines+markers'
               )
)
fig.add_trace(
    go.Scatter(x = [ex.DATE[:init].iloc[-1]],
               y = [ex.Bolivia[:init].iloc[-1]],
               text = [round(ex.Bolivia[:init].iloc[-1],2)],
               textfont = dict(color = 'black', size = 10),
               textposition = 'middle right',
               mode = 'markers+text', 
               marker = dict(color = 'rgb(60, 179, 113)', size = 5, symbol = 'circle', line=dict(width=2, color = 'black')),
               showlegend = False)
)
fig.add_trace(
    go.Scatter(x = ex.DATE[:init],
               y = ex.Perú[:init],
               name = 'Perú',
               visible = True,
               line = dict(color = 'rgb(139, 0, 0)'),
               mode = 'lines+markers'
               )
)
fig.add_trace(
    go.Scatter(x = [ex.DATE[:init].iloc[-1]],
               y = [ex.Perú[:init].iloc[-1]],
               text = [round(ex.Perú[:init].iloc[-1],2)],
               textfont = dict(color = 'black', size = 10),
               textposition = 'middle right',
               mode = 'markers+text', 
               marker = dict(color = 'rgb(139, 0, 0)', size = 5, symbol = 'circle', line=dict(width=2, color = 'black')),
               showlegend = False)
)
fig.add_trace(
    go.Scatter(x = ex.DATE[:init],
               y = ex.Brasil[:init],
               name = 'Brasil',
               visible = True,
               line = dict(color = 'rgb(0, 100, 0)'),
               mode = 'lines+markers'
               )
)
fig.add_trace(
    go.Scatter(x = [ex.DATE[:init].iloc[-1]],
               y = [ex.Brasil[:init].iloc[-1]],
               text = [round(ex.Brasil[:init].iloc[-1],2)],
               textfont = dict(color = 'black', size = 10),
               textposition = 'middle right',
               mode = 'markers+text', 
               marker = dict(color = 'rgb(0, 100, 0)', size = 5, symbol = 'circle', line=dict(width=2, color = 'black')),
               showlegend = False)
)
fig.add_trace(
    go.Scatter(x = ex.DATE[:init],
               y = ex.Ecuador[:init],
               name = 'Ecuador',
               visible = True,
               line = dict(color = 'rgb(0, 0, 205)'),
               mode = 'lines+markers'
               )
)
fig.add_trace(
    go.Scatter(x = [ex.DATE[:init].iloc[-1]],
               y = [ex.Ecuador[:init].iloc[-1]],
               text = [round(ex.Ecuador[:init].iloc[-1],2)],
               textfont = dict(color = 'black', size = 10),
               textposition = 'middle right',
               mode = 'markers+text', 
               marker = dict(color = 'rgb(0, 0, 205)', size = 5, symbol = 'circle', line=dict(width=2, color = 'black')),
               showlegend = False)
)
fig.add_trace(
    go.Scatter(x = ex.DATE[:init],
               y = ex.Venezuela[:init],
               name = 'Venezuela',
               visible = True,
               line = dict(color = 'rgb(255, 165, 0)'),
               mode = 'lines+markers'
               )
)
fig.add_trace(
    go.Scatter(x = [ex.DATE[:init].iloc[-1]],
               y = [ex.Venezuela[:init].iloc[-1]],
               text = [round(ex.Venezuela[:init].iloc[-1],2)],
               textfont = dict(color = 'black', size = 10),
               textposition = 'middle right',
               mode = 'markers+text', 
               marker = dict(color =  'rgb(255, 165, 0)', size = 5, symbol = 'circle', line=dict(width=2, color = 'black')),
               showlegend = False)
)
fig.add_trace(
    go.Scatter(x = ex.DATE[:init],
               y = ex.Paraguay[:init],
               name = 'Paraguay',
               visible = True,
               line = dict(color = 'rgb(32, 178, 170)'),
               mode = 'lines+markers'
               )
)
fig.add_trace(
    go.Scatter(x = [ex.DATE[:init].iloc[-1]],
               y = [ex.Paraguay[:init].iloc[-1]],
               text = [round(ex.Paraguay[:init].iloc[-1],2)],
               textfont = dict(color = 'black', size = 10),
               textposition = 'middle right',
               mode = 'markers+text', 
               marker = dict(color = 'rgb(32, 178, 170)', size = 5, symbol = 'circle', line=dict(width=2, color = 'black')),
               showlegend = False)
)
fig.add_trace(
    go.Scatter(x = ex.DATE[:init],
               y = ex.Uruguay[:init],
               name = 'Uruguay',
               visible = True,
               line = dict(color = 'rgb(65, 105, 225)'),
               mode = 'lines+markers'
               )
)
fig.add_trace(
    go.Scatter(x = [ex.DATE[:init].iloc[-1]],
               y = [ex.Uruguay[:init].iloc[-1]],
               text = [round(ex.Uruguay[:init].iloc[-1],2)],
               textfont = dict(color = 'black', size = 10),
               textposition = 'middle right',
               mode = 'markers+text', 
               marker = dict(color = 'rgb(65, 105, 225)', size = 5, symbol = 'circle', line=dict(width=2, color = 'black')),
               showlegend = False)
)

# Add endpoint markert and the value
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Frames 
frames = [
    go.Frame(
        data = [
            go.Scatter(x = ex.DATE[:k], y = ex.Chile[:k]),
            go.Scatter(x = [ex.DATE[:k].iloc[-1]],y = [ex.Chile[:k].iloc[-1]], text = [round(ex.Chile[:k].iloc[-1],2)]),
            go.Scatter(x = ex.DATE[:k], y = ex.Argentina[:k]),
            go.Scatter(x = [ex.DATE[:k].iloc[-1]],y = [ex.Argentina[:k].iloc[-1]], text = [round(ex.Argentina[:k].iloc[-1],2)]),
            go.Scatter(x = ex.DATE[:k], y = ex.Colombia[:k]),
            go.Scatter(x = [ex.DATE[:k].iloc[-1]],y = [ex.Colombia[:k].iloc[-1]], text = [round(ex.Colombia[:k].iloc[-1],2)]),
            go.Scatter(x = ex.DATE[:k], y = ex.Bolivia[:k]),
            go.Scatter(x = [ex.DATE[:k].iloc[-1]],y = [ex.Bolivia[:k].iloc[-1]], text = [round(ex.Bolivia[:k].iloc[-1],2)]),
            go.Scatter(x = ex.DATE[:k], y = ex.Perú[:k]),
            go.Scatter(x = [ex.DATE[:k].iloc[-1]],y = [ex.Perú[:k].iloc[-1]], text = [round(ex.Perú[:k].iloc[-1],2)]),
            go.Scatter(x = ex.DATE[:k], y = ex.Venezuela[:k]),
            go.Scatter(x = [ex.DATE[:k].iloc[-1]],y = [ex.Venezuela[:k].iloc[-1]], text = [round(ex.Venezuela[:k].iloc[-1],2)]),
            go.Scatter(x = ex.DATE[:k], y = ex.Ecuador[:k]),
            go.Scatter(x = [ex.DATE[:k].iloc[-1]],y = [ex.Ecuador[:k].iloc[-1]], text = [round(ex.Ecuador[:k].iloc[-1],2)]),
            go.Scatter(x = ex.DATE[:k], y = ex.Uruguay[:k]),
            go.Scatter(x = [ex.DATE[:k].iloc[-1]],y = [ex.Uruguay[:k].iloc[-1]], text = [round(ex.Uruguay[:k].iloc[-1],2)]),
            go.Scatter(x = ex.DATE[:k], y = ex.Paraguay[:k]),
            go.Scatter(x = [ex.DATE[:k].iloc[-1]],y = [ex.Paraguay[:k].iloc[-1]], text = [round(ex.Paraguay[:k].iloc[-1],2)]),
            go.Scatter(x = ex.DATE[:k], y = ex.Brasil[:k]),
            go.Scatter(x = [ex.DATE[:k].iloc[-1]],y = [ex.Brasil[:k].iloc[-1]], text = [round(ex.Brasil[:k].iloc[-1],2)])
        ]
    )
    for k in range(init, len(ex)+1)
]

# %%
# More formating
fig.update_xaxes(title = 'Date', title_font_size = 20,
                 dtick = 'M1')

## Legend
fig.update_layout(legend=dict(
                  orientation="h",
                  yanchor="middle",
                  y=-0.25,
                  xanchor="center",
                  x=0.5))
#
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Animation
fig.update(frames = frames)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Buttons 
fig.update_layout(
    updatemenus = [
        dict(
            buttons = list([
                dict(label = 'Play',
                     method = 'animate',
                     args = [None, {'frame':{'duration':300}}]
                     )
                 ]
             )
        )
    ]
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
style.use('dark_background')

# %% [markdown]
# #**3. What is main take-away of DV?**

# %% [markdown]
# The main idea of the DV is to demonstrate the growth of the GDP per capita of the countries of South America, that is, the per capita income of each country over the years to show which economy has grown and which has decreased.
