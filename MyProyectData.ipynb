# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentinaGiraldo0/Code_in_class/blob/main/MyProyectData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**1. Variable.**

# %% [markdown]
# ## 1.1. Variable Name.

# %% [markdown]
# The variable that will be used to perform the visualization is the GDP per capita (USD at current prices) of South America.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1.2. Period or dates and frecuency.

# %% [markdown]
# The period for GDP per capita (USD at current prices) is between the years 1960 to 2021, with annual data.

# %% [markdown]
# ![Time series](https://aprendeconeli.com/wp-content/uploads/2020/05/AdobeStock_300167162-scaled.jpeg)

# %% [markdown]
# ## 1.3. Sources

# %% [markdown]
# The main source of information is the world bank
#
# [Banco Mundial](https://datos.bancomundial.org/indicador/NY.GDP.PCAP.CD?end=2021&locations=CO-AR-CL-BR-UY-PY-EC-VE-BO-PE&start=1960)

# %% [markdown]
# ![Time series](https://www.ebankingnews.com/wp-content/uploads/2019/02/bank-01.jpg)

# %% [markdown]
# #**2. Goal of the DV.**

# %% [markdown]
# ## 2.1. Story.

# %% [markdown]
# The variable was chosen with the objective of showing the growth or decrease of the GDP per capita in the countries of South America, where it is evident which economy is doing better over the years, since the quality of life of the population generally depends on of the growth of this and in this way, does Colombia have a good quality of life, as proposed by the current government to live tasty?

# %% [markdown]
# ![History](https://www.mooc.org/hubfs/history.jpg)

# %% [markdown]
# ## 2.2. Audience.

# %% [markdown]
# This information is aimed at people such as families, economic analysts and the general population. This with the aim of knowing and comparing the economic growth of a country, since the quality of life of the population improves when the GDP per capita increases.

# %% [markdown]
# ![Audience](https://img.freepik.com/vector-premium/coleccion-dibujos-animados-personajes-varias-personas_131454-651.jpg?w=2000)

# %% [markdown]
# ## 2.3. Justify the DV Type.

# %% [markdown]
# The dynamic line graph reflects at a glance and easily the changes provided by the aforementioned variable comparing the years mentioned, with an added value that links the total population.

# %% [markdown]
# ![Example DV](http://4.bp.blogspot.com/-Z2TYFVcsF6U/TjBTMoM16EI/AAAAAAAAAAk/61_KLjsXj9k/s1600/PIN+PER+CAPITA+COLOMBIA.png)

# %% [markdown]
# #**3. Examples.**

# %% [markdown]
# ## **3.1. Line Chart Example**

# %% [markdown]
# [Line chart example](https://www.tiktok.com/@piechartpirate/video/7000389386554592518?_t=8VDwrqOygKc&_r=1)

# %% [markdown]
# ### 3.1.1. Story

# %% [markdown]
# This graph represents the governments with the highest debt, as a percentage of GDP and how events in history such as the second world war affected them and the pandemic

# %% [markdown]
# ### 3.1.2. Audience

# %% [markdown]
# People interested in the history or credit of the countries

# %% [markdown]
# ### 3.1.3. Justify the DV Type

# %% [markdown]
# The graph is ideal because over the years the changes in the percentage of the debt of each country are evidenced, evidencing the difference of each country

# %% [markdown]
# ## 3.2. Dynamic bar chart

# %% [markdown]
# [Example with *dynamic bar chart*](https://www.tiktok.com/@piechartpirate/video/7110982945212468486?_t=8VHHzk6YQ1F&_r=1)

# %% [markdown]
# ### 3.2.1 Story

# %% [markdown]
# This graph shows the largest coffee producers in the world, with their due percentage.

# %% [markdown]
# ### 3.2.3 Audicence

# %% [markdown]
# This graph is aimed at coffee exporters to know their percentage and determine their growth in the world

# %% [markdown]
# ### 3.2.3 Justify the DV Type

# %% [markdown]
# The graph is represented in bars where the percentage of each country is clearly evidenced over the years.
