# %% [markdown]
# <a href="https://colab.research.google.com/github/ValentinaGiraldo0/Code_in_class/blob/main/MyProyectData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**1. Variable.**

# %% [markdown]
# ## 1.1. Variable Name.

# %% [markdown]
# The variable that will be used to perform the visualization is the GDP per capita of South America.

# %% [markdown]
# ![GDP per Capita](https://img.freepik.com/vector-premium/pib-o-producto-interno-bruto-per-capita_101179-1257.jpg?w=2000)

# %% [markdown]
# ## 1.2. Period or dates and frecuency.

# %% [markdown]
# The period for GDP per capita is between the years 1960 to 2021, with annual data.

# %% [markdown]
# ![Time series](https://aprendeconeli.com/wp-content/uploads/2020/05/AdobeStock_300167162-scaled.jpeg)

# %% [markdown]
# ## 1.3. Sources

# %% [markdown]
# The main source of information is the world bank
#
# [Banco Mundial](https://datos.bancomundial.org/indicador/NY.GDP.PCAP.CD?end=2021&locations=CO-AR-CL-BR-UY-PY-EC-VE-BO-PE&start=1960)

# %% [markdown]
# ![Time series](https://img.freepik.com/vector-premium/edificio-banco-retro-dibujos-animados-o-palacio-justicia-columnas-ilustracion-aislado-blanco_166005-61.jpg?w=2000)

# %% [markdown]
# #**2. Goal of the DV.**

# %% [markdown]
# ## 2.1. Story.

# %% [markdown]
# The variable was chosen with the objective of showing the growth or decrease of GDP per capita in the countries of South America, where it is evident which economy is better over the years.

# %% [markdown]
# ![History](data:image/png;base64,...)

# %% [markdown]
# ## 2.2. Audience.

# %% [markdown]
# This information is aimed at people such as families, economic analysts and the general population. This with the aim of knowing and comparing the economic growth of a country, since the quality of life of the population improves when the GDP per capita increases.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.3. Justify the DV Type.

# %% [markdown]
# The dynamic line graph reflects at a glance and easily the changes provided by the aforementioned variable comparing the years mentioned, with an added value that links the total population.

# %% [markdown]
# ![Example DV](https://d31dn7nfpuwjnm.cloudfront.net/images/valoraciones/0025/9896/Perspectiva_de_la_Bolsa_de_Valores_2017.png?1484889494)

# %% [markdown]
# #**3. Examples.**

# %% [markdown]
# [Line chart example](https://www.tiktok.com/@piechartpirate/video/7000389386554592518?_t=8VDwrqOygKc&_r=1)

# %% [markdown]
# [Line chart example](https://www.tiktok.com/@piechartpirate/video/6975893733824941317?_t=8VDx01RvVwr&_r=1)

# %% [markdown]
# [Example with *dynamic bar chart*](https://www.facebook.com/normasapa.pro/videos/pib-per-c%C3%A1pita-latinoam%C3%A9rica-1960-2025/2758958704353072/)
